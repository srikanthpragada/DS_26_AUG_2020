# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.1.3'

# %%
plt.isinteractive()
# Out:
# True

# %%
tips = sns.load_dataset('tips')

# %%
day_total = tips.groupby('day', as_index=False)['total_bill'].sum()
day_total
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %% [markdown]
# ## Line Graph

# %%
plt.plot(day_total['day'], day_total['total_bill'])  # Line Graph
plt.xlabel("Day")
plt.ylabel("Total Bill")
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
plt.title("Day-wise Total Bill")
plt.xlabel("Day")
plt.ylabel("Total Bill")
#plt.plot(day_total['day'], day_total['total_bill'],color='red', linestyle='dashed',  linewidth=4)
plt.plot(day_total['day'], day_total['total_bill'],'--r',linewidth=2, markersize=12)
plt.plot(day_total['day'], day_total['total_bill'],'bo', markersize=12)

# %%
male = tips[ tips.sex == 'Male']
maletotal = male.groupby('day', as_index = False)['total_bill'].sum()
female = tips[ tips.sex == 'Female']
femaletotal = female.groupby('day', as_index = False)['total_bill'].sum()

plt.plot(maletotal['day'], maletotal['total_bill'],color='red', label="Male")
plt.plot(femaletotal['day'], femaletotal['total_bill'],color='blue', label="Female")
plt.legend(loc='upper left')
plt.xlabel("Day")
plt.ylabel("Sum of Total Bill")
plt.title("Total Bill by Sex")
#plt.ylim(0,1500)  # Change Y-Axis scale
# Out:
# Text(0.5, 1.0, 'Total Bill by Sex')

# %% [markdown]
# ## Bar Graph

# %%
plt.bar(day_total['day'], day_total['total_bill'], color='green', width=.5)
plt.title("Day-wise Total Bill")
plt.xlabel("Day")
plt.ylabel("Total Bill")
x = plt.yticks(np.arange(200,2000,step=200))

# %% [markdown]
# ## Pie chart

# %%
plt.pie(day_total['total_bill'], labels = day_total['day'])
x = plt.title("Day-wise Total Bill")

# %%
plt.pie(day_total['total_bill'], labels = day_total['day'], autopct ="%.2f")
x = plt.title("Day-wise Total Bill")

# %%
ax = plt.pie(day_total['total_bill'], labels = day_total['day'], autopct ="%.2f",
             explode = (0,0,0.0,0.1))
x = plt.title("Day-wise Total Bill")

# %%
ax
# Out:
# (([<matplotlib.patches.Wedge at 0x1f33439af08>,
#    <matplotlib.patches.Wedge at 0x1f3343a3a48>,
#    <matplotlib.patches.Wedge at 0x1f3343a78c8>,
#    <matplotlib.patches.Wedge at 0x1f3343af788>],
#   [Text(0.8317418198604141, 0.7198649492059511, 'Thur'),
#    Text(-0.07485481766878774, 1.0974501156188252, 'Fri'),
#    Text(-1.0902316372510155, 0.1462702195833805, 'Sat'),
#    Text(0.5878521216514081, -1.0461500289489736, 'Sun')],
#   [Text(0.4536773562874985, 0.3926536086577915, '22.71'),
#    Text(-0.04082990054661149, 0.5986091539739046, '6.75'),
#    Text(-0.5946718021369175, 0.07978375613638934, '36.84'),
#    Text(0.34291373762998806, -0.6102541835535678, '33.70')]),
#  tuple)

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(tips['total_bill'], tips['tip'], c = 'green', marker='o', s = 50)
plt.title("Total Bill vs. Tip")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
# plt.xlim((0,80))  # X Scale 
# plt.ylim((0,15)) 
plt.gcf().set_size_inches(15,5)

# %%
male_trans = tips.loc [ tips.sex == 'Male',:]
female_trans = tips.loc [ tips.sex == 'Female',:]

# %%
plt.scatter(male_trans['total_bill'], male_trans['tip'], c = 'green', marker='+', label='Male')
plt.scatter(female_trans['total_bill'], female_trans['tip'], c = 'red', marker= 'd', label='Female')
plt.title("Total Bill vs. Tip for Male and Female")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.legend()
plt.gcf().set_size_inches(15,5)

# %%
plt.scatter(tips['size'], tips['total_bill'])
plt.title("Total Bill vs. Size")
plt.xlabel("Size")
plt.ylabel("Total Bill")
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
plt.scatter(tips['size'], tips['tip'])
plt.title("Tip vs. Size")
plt.xlabel("Size")
plt.ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ## Box Plot

# %%
plt.boxplot(tips['total_bill'],showmeans=True, meanline=True)
plt.title("Total Bill")
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %%
prop = {'color':'red', 'linewidth' : 3, 'linestyle' : 'solid'}
ax = plt.boxplot(tips['tip'], showfliers=False, showmeans=True, meanline=True, boxprops=prop)

# %% [markdown]
# ## Histogram

# %%
plt.title("Total Bill")
ax = plt.hist(tips['total_bill'])

# %%
ax = tips.tip.hist()

# %%
plt.hist(tips['total_bill'], bins=[0,10,20,30,40,50,60])
plt.title("Total Bill")
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %%
plt.title("Total Bill")
t = plt.hist(tips['total_bill'], bins=5)

# %% [markdown]
# ## Object API

# %%
ax = plt.subplot()
print(type(ax))
ax.bar(day_total['day'], day_total['total_bill'])
ax.set_title("Day-wise Total Bill")
ax.set_xlabel("Day")
ax.set_ylabel("Total Bill")
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# Text(0, 0.5, 'Total Bill')

# %%
fig,ax = plt.subplots(1,2)
fig.suptitle('Day-wise Total', fontsize=14, color='blue')
fig.set_size_inches(15,4)
# First Axes - bar graph
ax[0].bar(day_total['day'], day_total['total_bill'], color='red')
ax[0].set_xlabel("Day")
ax[0].set_ylabel("Total Bill")
# Second Axes - line graph
ax[1].plot(day_total['day'], day_total['total_bill'], linewidth=4)
ax[1].set_xlabel("Day")
ax[1].set_ylabel("Total Bill")
fig.savefig("day_total.jpg")

# %% [markdown]
# ### Text

# %%
plt.plot(day_total['day'], day_total['total_bill'])
# set labels for dots
days = day_total['day']
totals = day_total['total_bill']
for (x,y) in zip(days,totals):
    plt.text(x,y + 50,f"{y:.0f}", fontdict= {'color': 'red'})

# %%
countries = pd.read_json("https://restcountries.eu/rest/v2/all")
# Take only top 5 countries by population
tc = countries.nlargest(5,'population')
plt.scatter(x = tc ['area'], y = tc ['population'])
plt.gcf().set_size_inches (8,5)   # gcf () get current figure and change its size     
plt.xlabel("Area")
plt.ylabel("Population")

# set labels for dots
for pos,i in enumerate(tc.index):
     plt.text(tc.loc[i,'area'] + 100000, tc.loc[i,'population'], f"{tc.loc[i,'alpha3Code'] + ':' + str(pos+1)}")

# %%
# smoker_total  = pd.crosstab(tips['day'], tips['smoker'], tips['total_bill'], aggfunc=sum)
smoker_total  = tips.pivot_table(index='day', columns='smoker',values= 'total_bill',aggfunc=sum)

# %%
smoker_total
# Out:
# smoker     Yes       No
# day
# Thur    326.24   770.09
# Fri     252.20    73.68
# Sat     893.62   884.78
# Sun     458.28  1168.88

# %% [markdown]
# ### Stacked bar

# %%
ax = plt.subplot()
ax.bar(smoker_total.index , height=smoker_total['Yes'], label="Smokers")
ax.bar(smoker_total.index , height=smoker_total['No'],bottom = smoker_total["Yes"],  label="Non Smokers")
ax.legend()

# %%
smoker_total.plot.bar(stacked=True)

# %% [markdown]
# ### Multi-column Bar Graph

# %%
ax = smoker_total.plot.bar()
ax.set_ylabel('Total Bill')
ax.set_title('Total Bill Per Day for Smokers vs. Non-Smokers')
# Out:
# Text(0.5, 1.0, 'Total Bill Per Day for Smokers vs. Non-Smokers')

# %%
smoker_total.plot.line()

# %%
smoker_total.plot.line(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000240B3C123C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000240B20AB088>],
#       dtype=object)

# %%
totals  = pd.crosstab(tips['sex'],tips['day' ], tips['total_bill'], aggfunc=sum)

# %%
totals
# Out:
# day       Thur     Fri      Sat      Sun
# sex
# Male    561.44  198.57  1227.35  1269.46
# Female  534.89  127.31   551.05   357.70

# %%
totals.plot(kind='bar', figsize=(10,5))

# %%
totals.plot.bar(stacked=True)

# %% [markdown]
# ### Line Graph

# %%
male = tips.loc[ tips['sex'] == 'Male'].groupby('day')['total_bill'].sum()
female  = tips.loc[ tips['sex'] == 'Female'].groupby('day')['total_bill'].sum()

# %%
plt.plot(male, color='blue',linewidth=5)
plt.plot(female, color='pink', linewidth=5)
plt.legend(['Male','Female'])

# %% [markdown]
# ### Histogram

# %%
ax = tips.hist()
#ax[0,0].set_title("Table Size")

# %%
ax = tips[['total_bill','tip']].hist()

# %%
countries['region'].value_counts()
# Out:
# Africa      60
# Americas    57
# Europe      53
# Asia        50
# Oceania     27
#              2
# Polar        1
# Name: region, dtype: int64

# %%
asia_top_10 = countries.loc[countries.region == 'Asia', ['name', 'population','area']].sort_values('population',ascending=False).head(10)

# %%
asia_top_10
# Out:
#                            name  population       area
# 48                        China  1377422166  9640011.0
# 104                       India  1295210000  3287590.0
# 105                   Indonesia   258705000  1904569.0
# 169                    Pakistan   194125062   881912.0
# 18                   Bangladesh   161006790   147570.0
# 114                       Japan   126960000   377930.0
# 176                 Philippines   103279800   342353.0
# 244                    Viet Nam    92700000   331212.0
# 107  Iran (Islamic Republic of)    79369900  1648195.0
# 231                      Turkey    78741053   783562.0

# %%
fig,(ax1,ax2) = plt.subplots(1,2)
fig.set_size_inches(15,5)
ax1.bar(asia_top_10['name'],asia_top_10['population'])
ax1.set_xticklabels(asia_top_10.name, rotation = 'vertical')
ax2.bar(asia_top_10['name'],asia_top_10['area'])
x = ax2.set_xticklabels(asia_top_10.name, rotation = 80)
